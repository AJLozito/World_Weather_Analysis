# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# myaundzha ru
# baykit ru
# ushuaia ar
# grand river south east mu
# dikson ru
# saint george bm
# victoria sc
# manado id
# dikson ru
# ardakan ir
# cape town za
# avarua ck
# port alfred za
# cabo san lucas mx
# kavieng pg
# illoqqortoormiut gl
# hilo us
# pokhara np
# ushuaia ar
# laguna br
# busselton au
# roswell us
# zhezkazgan kz
# santa maria cv
# yulara au
# road town vg
# busselton au
# port macquarie au
# hithadhoo mv
# albany au
# ponta do sol cv
# sur om
# richards bay za
# saint-philippe re
# rikitea pf
# slave lake ca
# bethel us
# mys shmidta ru
# bredasdorp za
# punta arenas cl
# upernavik gl
# ushuaia ar
# hermanus za
# jamestown sh
# bhadrapur np
# yellowknife ca
# cape town za
# blagoyevo ru
# illoqqortoormiut gl
# rikitea pf
# cabo san lucas mx
# cherskiy ru
# kruisfontein za
# georgetown sh
# nuevo progreso mx
# kapaa us
# sivaki ru
# sorland no
# pringsewu id
# general pico ar
# kaseda jp
# chokurdakh ru
# samusu ws
# jabiru au
# provideniya ru
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=96d5eabf6192b79649851109837baf6e

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Make a loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 (in order to log)
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Generate an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers by city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each city
    try:
    
        # Parse up the JSON content and retrieve the data
        city_weather = requests.get(city_url).json()
        
        # Parse out the required data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Format the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city details into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is occures, skip the city
    except:
        print("City not found. Skipping...")
        pass


# Create a data retrieval confirmation screen
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | myaundzha
# Processing Record 2 of Set 1 | baykit
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | manado
# Processing Record 9 of Set 1 | ardakan
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | pokhara
# Processing Record 18 of Set 1 | laguna
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | roswell
# ...

# %%
len(city_data)
# Out:
# 673

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Myaundzha  63.0494  147.1858    -23.08        88          32
# 1        Baykit  61.6700   96.3700    -23.80       100          73
# 2       Ushuaia -54.8000  -68.3000     40.66        93          40
# 3        Dikson  73.5069   80.5464    -18.56        92          96
# 4  Saint George  37.1041 -113.5841     66.94        13          39
# 5      Victoria  22.2855  114.1577     63.25        80          97
# 6        Manado   1.4870  124.8455     77.77        94          40
# 7       Ardakan  32.3100   54.0175     44.98        38           0
# 8     Cape Town -33.9258   18.4232     70.88        76          75
# 9        Avarua -21.2078 -159.7750     78.85        89          40
#
#    Wind Speed Country Current Description                 Date
# 0        3.22      RU    scattered clouds  2022-02-15 23:57:24
# 1        2.24      RU       broken clouds  2022-02-15 23:57:24
# ...

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Myaundzha      RU  63.0494  147.1858    -23.08        88          32
# 1          Baykit      RU  61.6700   96.3700    -23.80       100          73
# 2         Ushuaia      AR -54.8000  -68.3000     40.66        93          40
# 3          Dikson      RU  73.5069   80.5464    -18.56        92          96
# 4    Saint George      US  37.1041 -113.5841     66.94        13          39
# ..            ...     ...      ...       ...       ...       ...         ...
# 668        Papara      BR  -3.9839  -38.7273     80.69        93          13
# 669       Mallaig      CA  54.2169 -111.3685      6.71        88          97
# 670      Yar-Sale      RU  66.8333   70.8333    -15.34        99          38
# 671     Karpathos      GR  35.5070   27.2132     55.36        67           0
# 672     Mporokoso      ZM  -9.3727   30.1250     57.72        97         100
#
# ...

# %%
# Create the output file (CSV)
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
